# %%
from src.training.training_process import create_training_config, perform_training

config = create_training_config()

perform_training(config)
# Out:
# Epoch 1: 100%|██████████| 13/13 [08:25<00:00, 38.89s/it, G_loss=91.4720 - 176.3184, D_loss=1.8988 - 1.9001, Mel_loss=8.9502 - 17.4344, Dur_loss=0.6856 - 1.0587]
# Epoch 2: 100%|██████████| 13/13 [08:16<00:00, 38.22s/it, G_loss=88.0048 - 172.8924, D_loss=1.8945 - 1.8985, Mel_loss=8.6779 - 17.1155, Dur_loss=0.6080 - 1.0384]
# Epoch 3: 100%|██████████| 13/13 [07:43<00:00, 35.64s/it, G_loss=94.5257 - 197.4485, D_loss=1.8784 - 1.8940, Mel_loss=9.2807 - 19.5431, Dur_loss=0.6360 - 1.0021]
# Epoch 4: 100%|██████████| 13/13 [08:00<00:00, 36.97s/it, G_loss=114.9725 - 201.6712, D_loss=1.8154 - 1.8765, Mel_loss=11.3557 - 20.0384, Dur_loss=0.5977 - 0.9619]
# Epoch 5: 100%|██████████| 13/13 [08:03<00:00, 37.17s/it, G_loss=79.8563 - 183.7753, D_loss=1.7447 - 1.8573, Mel_loss=7.7802 - 18.2153, Dur_loss=0.6021 - 0.9131]
# Epoch 6: 100%|██████████| 13/13 [08:02<00:00, 37.08s/it, G_loss=87.0414 - 159.4017, D_loss=1.4304 - 1.7199, Mel_loss=8.4889 - 15.6567, Dur_loss=0.6259 - 0.9959]
# Epoch 7: 100%|██████████| 13/13 [08:05<00:00, 37.33s/it, G_loss=106.5588 - 206.7811, D_loss=1.0705 - 1.5178, Mel_loss=10.3759 - 20.3894, Dur_loss=0.6070 - 0.9653]
# Epoch 8:  69%|██████▉   | 9/13 [05:58<02:45, 41.43s/it, G_loss=84.7188 - 183.5327, D_loss=1.0017 - 1.4874, Mel_loss=8.1666 - 18.0647, Dur_loss=0.6321 - 0.9322]
# ✅ Saved checkpoint at step 100
# Epoch 8: 100%|██████████| 13/13 [08:31<00:00, 39.38s/it, G_loss=84.7188 - 183.5327, D_loss=1.0017 - 1.5129, Mel_loss=8.1666 - 18.0647, Dur_loss=0.5696 - 0.9322]
# Epoch 9: 100%|██████████| 13/13 [09:23<00:00, 43.31s/it, G_loss=104.3247 - 170.1780, D_loss=1.1127 - 1.3995, Mel_loss=10.1507 - 16.7258, Dur_loss=0.5899 - 0.8452]
# Epoch 10: 100%|██████████| 13/13 [09:34<00:00, 44.22s/it, G_loss=95.8992 - 185.2187, D_loss=0.9891 - 1.3877, Mel_loss=9.3441 - 18.2134, Dur_loss=0.6007 - 0.8146]
# Epoch 11: 100%|██████████| 13/13 [09:25<00:00, 43.48s/it, G_loss=71.8011 - 177.1175, D_loss=0.9119 - 1.5095, Mel_loss=6.9421 - 17.4135, Dur_loss=0.5970 - 1.0912]
# Epoch 12: 100%|██████████| 13/13 [09:13<00:00, 42.58s/it, G_loss=91.5993 - 195.2756, D_loss=0.8633 - 1.4787, Mel_loss=8.8978 - 19.1708, Dur_loss=0.5588 - 0.8214]
# Epoch 13: 100%|██████████| 13/13 [09:37<00:00, 44.40s/it, G_loss=96.1840 - 175.4946, D_loss=1.0019 - 1.3854, Mel_loss=9.3509 - 17.2253, Dur_loss=0.5519 - 0.9028]
# Epoch 14: 100%|██████████| 13/13 [08:52<00:00, 40.94s/it, G_loss=107.8225 - 188.7888, D_loss=0.9122 - 1.3354, Mel_loss=10.5081 - 18.5140, Dur_loss=0.5533 - 0.9711]
# Epoch 15: 100%|██████████| 13/13 [08:59<00:00, 41.53s/it, G_loss=94.2020 - 181.9468, D_loss=0.8479 - 1.3955, Mel_loss=9.1563 - 17.8537, Dur_loss=0.5487 - 0.8523]
# Epoch 16:  38%|███▊      | 5/13 [03:17<05:06, 38.36s/it, G_loss=95.2011 - 173.2598, D_loss=0.9747 - 1.3554, Mel_loss=9.2340 - 16.9598, Dur_loss=0.5685 - 0.7946]
# ✅ Saved checkpoint at step 200
# Epoch 16: 100%|██████████| 13/13 [08:56<00:00, 41.30s/it, G_loss=95.2011 - 173.2598, D_loss=0.9437 - 1.4069, Mel_loss=9.2340 - 16.9598, Dur_loss=0.5685 - 1.0065]
# Epoch 17: 100%|██████████| 13/13 [09:13<00:00, 42.56s/it, G_loss=102.1583 - 172.4146, D_loss=0.9320 - 1.3707, Mel_loss=9.9356 - 16.8249, Dur_loss=0.5106 - 0.8933]
# Epoch 18: 100%|██████████| 13/13 [09:29<00:00, 43.82s/it, G_loss=76.4977 - 169.5677, D_loss=0.9555 - 1.5052, Mel_loss=7.3977 - 16.6012, Dur_loss=0.5561 - 0.9436]
# Epoch 19: 100%|██████████| 13/13 [09:31<00:00, 43.93s/it, G_loss=101.8877 - 172.9780, D_loss=0.9776 - 1.3253, Mel_loss=9.8607 - 16.9323, Dur_loss=0.6055 - 0.8910]
# Epoch 20: 100%|██████████| 13/13 [09:06<00:00, 42.01s/it, G_loss=95.1426 - 173.7868, D_loss=0.8687 - 1.4306, Mel_loss=9.2028 - 16.9172, Dur_loss=0.5471 - 0.8905]
# Epoch 21:  85%|████████▍ | 11/13 [08:38<01:34, 47.12s/it, G_loss=95.5624 - 197.7501, D_loss=0.9282 - 1.3604, Mel_loss=9.1888 - 19.3481, Dur_loss=0.6200 - 0.9828]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 from src.training.training_process import create_training_config, perform_training
#       2
#       3 config = create_training_config()
#       4
# ----> 5 perform_training(config)
#
# File ~\Obsidiwan\Work\AI\voice-cloning\src\training\training_process.py:88, in perform_training(config)
#      85 dur_loss = SmallDataAggregator()
#      87 for batch in progres_bar:
# ---> 88     losses = train_step(config, batch)
#      90     progres_bar.set_postfix({
#      91         "G_loss": g_loss.accept_data(losses['g_loss']),
#      92         "D_loss": d_loss.accept_data(losses['d_loss']),
#      93         "Mel_loss": mel_loss.accept_data(losses['mel_loss']),
#      94         "Dur_loss": dur_loss.accept_data(losses['dur_loss']),
#      95     })
#      97     global_step += 1
#
# File ~\Obsidiwan\Work\AI\voice-cloning\src\training\step.py:113, in train_step(config, batch)
#     104     return {
#     105         "g_loss": 0.0,
#     106         "d_loss": 0.0,
#    (...)    109         "skipped": True
#     110     }
#     112 # Backprop
# --> 113 final_g_loss.backward()
#     114 # torch.nn.utils.clip_grad_norm_(model.generator.parameters(), max_norm=1.0)
#     115 config.optimizer_g.step()
#
# File ~\Obsidiwan\Work\AI\voice-cloning\.venv\Lib\site-packages\torch\_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File ~\Obsidiwan\Work\AI\voice-cloning\.venv\Lib\site-packages\torch\autograd\__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File ~\Obsidiwan\Work\AI\voice-cloning\.venv\Lib\site-packages\torch\autograd\graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:
