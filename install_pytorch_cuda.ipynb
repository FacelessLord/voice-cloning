# %%
# !pip install torch torchvision torchaudio torchcodec --index-url https://download.pytorch.org/whl/cu130
# !pip install -r .\requirements.txt
# !pip install transformers==5.10.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu132
# Requirement already satisfied: torch in .\.venv\Lib\site-packages (2.12.0+cu130)
# Requirement already satisfied: torchvision in .\.venv\Lib\site-packages (0.27.0+cu130)
# Requirement already satisfied: torchaudio in .\.venv\Lib\site-packages (2.11.0+cu130)
# Requirement already satisfied: filelock in .\.venv\Lib\site-packages (from torch) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\.venv\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in .\.venv\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in .\.venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\.venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in .\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\.venv\Lib\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (from torchvision) (2.4.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in .\.venv\Lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\.venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: accelerate==1.13.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: annotated-doc==0.0.4 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: anyio==4.13.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 3)) (4.13.0)
# Requirement already satisfied: asttokens==3.0.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: audioread==3.1.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: certifi==2026.5.20 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 6)) (2026.5.20)
# Requirement already satisfied: cffi==2.0.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: charset-normalizer==3.4.7 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 8)) (3.4.7)
# Requirement already satisfied: click==8.4.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 9)) (8.4.1)
# Requirement already satisfied: colorama==0.4.6 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: comm==0.2.3 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: debugpy==1.8.21 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 12)) (1.8.21)
# Requirement already satisfied: decorator==5.3.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 13)) (5.3.1)
# Requirement already satisfied: diffusers==0.38.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 14)) (0.38.0)
# Requirement already satisfied: executing==2.2.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: ffmpeg==1.4 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 16)) (1.4)
# Requirement already satisfied: ffmpeg-python==0.2.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 17)) (0.2.0)
# Requirement already satisfied: filelock==3.29.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 18)) (3.29.1)
# Requirement already satisfied: fsspec==2026.4.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 19)) (2026.4.0)
# Requirement already satisfied: future==1.0.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 20)) (1.0.0)
# Requirement already satisfied: h11==0.16.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 21)) (0.16.0)
# Requirement already satisfied: hf-xet==1.5.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 22)) (1.5.0)
# Requirement already satisfied: httpcore==1.0.9 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 23)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 24)) (0.28.1)
# Requirement already satisfied: huggingface_hub==1.18.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 25)) (1.18.0)
# Requirement already satisfied: idna==3.18 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 26)) (3.18)
# Requirement already satisfied: importlib_metadata==9.0.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 27)) (9.0.0)
# Requirement already satisfied: ipykernel==7.2.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 28)) (7.2.0)
# Requirement already satisfied: ipython==9.14.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 29)) (9.14.1)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 30)) (1.1.1)
# Requirement already satisfied: ipywidgets==8.1.8 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 31)) (8.1.8)
# Requirement already satisfied: jedi==0.20.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 32)) (0.20.0)
# Requirement already satisfied: Jinja2==3.1.6 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 33)) (3.1.6)
# Requirement already satisfied: joblib==1.5.3 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 34)) (1.5.3)
# Requirement already satisfied: jupyter_client==8.9.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 35)) (8.9.0)
# Requirement already satisfied: jupyter_core==5.9.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 36)) (5.9.1)
# Requirement already satisfied: jupyterlab_widgets==3.0.16 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 37)) (3.0.16)
# Requirement already satisfied: lazy-loader==0.5 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 38)) (0.5)
# Requirement already satisfied: librosa==0.11.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 39)) (0.11.0)
# Requirement already satisfied: llvmlite==0.47.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 40)) (0.47.0)
# Requirement already satisfied: markdown-it-py==4.2.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 41)) (4.2.0)
# Requirement already satisfied: MarkupSafe==3.0.3 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 42)) (3.0.3)
# Requirement already satisfied: matplotlib-inline==0.2.2 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 43)) (0.2.2)
# Requirement already satisfied: mdurl==0.1.2 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 44)) (0.1.2)
# Requirement already satisfied: mpmath==1.3.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: msgpack==1.1.2 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 46)) (1.1.2)
# Requirement already satisfied: narwhals==2.22.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 47)) (2.22.1)
# Requirement already satisfied: nest-asyncio==1.6.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 48)) (1.6.0)
# Requirement already satisfied: networkx==3.6.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 49)) (3.6.1)
# Requirement already satisfied: numba==0.65.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 50)) (0.65.1)
# Requirement already satisfied: numpy==2.4.6 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 51)) (2.4.6)
# Requirement already satisfied: numpy-typing-compat==20251206.2.4 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 52)) (20251206.2.4)
# Requirement already satisfied: optype==0.17.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 53)) (0.17.1)
# Requirement already satisfied: packaging==26.2 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 54)) (26.2)
# Requirement already satisfied: parso==0.8.7 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 55)) (0.8.7)
# Requirement already satisfied: pillow==12.2.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 56)) (12.2.0)
# Requirement already satisfied: platformdirs==4.10.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 57)) (4.10.0)
# Requirement already satisfied: pooch==1.9.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 58)) (1.9.0)
# Requirement already satisfied: prompt_toolkit==3.0.52 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 59)) (3.0.52)
# Requirement already satisfied: psutil==7.2.2 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 60)) (7.2.2)
# Requirement already satisfied: pure_eval==0.2.3 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 61)) (0.2.3)
# Requirement already satisfied: pycparser==3.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 62)) (3.0)
# Requirement already satisfied: Pygments==2.20.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 63)) (2.20.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 64)) (2.9.0.post0)
# Requirement already satisfied: PyYAML==6.0.3 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 65)) (6.0.3)
# Requirement already satisfied: pyzmq==27.1.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 66)) (27.1.0)
# Requirement already satisfied: regex==2026.5.9 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 67)) (2026.5.9)
# Requirement already satisfied: requests==2.34.2 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 68)) (2.34.2)
# Requirement already satisfied: rich==15.0.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 69)) (15.0.0)
# Requirement already satisfied: safetensors==0.8.0rc1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 70)) (0.8.0rc1)
# Requirement already satisfied: scikit-learn==1.9.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 71)) (1.9.0)
# Requirement already satisfied: scipy==1.17.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 72)) (1.17.1)
# Requirement already satisfied: scipy-stubs==1.17.1.5 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 73)) (1.17.1.5)
# Requirement already satisfied: setuptools==81.0.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 74)) (81.0.0)
# Requirement already satisfied: shellingham==1.5.4 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 75)) (1.5.4)
# Requirement already satisfied: six==1.17.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 76)) (1.17.0)
# Requirement already satisfied: soundfile==0.14.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 77)) (0.14.0)
# Requirement already satisfied: soxr==1.1.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 78)) (1.1.0)
# Requirement already satisfied: stack-data==0.6.3 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 79)) (0.6.3)
# Requirement already satisfied: sympy==1.14.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 80)) (1.14.0)
# Requirement already satisfied: threadpoolctl==3.6.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 81)) (3.6.0)
# Requirement already satisfied: tokenizers==0.22.2 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 82)) (0.22.2)
# Requirement already satisfied: tornado==6.5.6 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 83)) (6.5.6)
# Requirement already satisfied: tqdm==4.68.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 84)) (4.68.1)
# Requirement already satisfied: traitlets==5.15.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 85)) (5.15.1)
# Requirement already satisfied: typer==0.25.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 86)) (0.25.1)
# Requirement already satisfied: typing_extensions==4.15.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 87)) (4.15.0)
# Requirement already satisfied: urllib3==2.7.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 88)) (2.7.0)
# Requirement already satisfied: uroman==1.3.1.1 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 89)) (1.3.1.1)
# Requirement already satisfied: wcwidth==0.8.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 90)) (0.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.15 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 91)) (4.0.15)
# Requirement already satisfied: zipp==4.1.0 in .\.venv\Lib\site-packages (from -r .\requirements.txt (line 92)) (4.1.0)
# Requirement already satisfied: torch>=2.0.0 in .\.venv\Lib\site-packages (from accelerate==1.13.0->-r .\requirements.txt (line 1)) (2.12.0+cu130)
# Requirement already satisfied: transformers==5.10.2 in .\.venv\Lib\site-packages (5.10.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in .\.venv\Lib\site-packages (from transformers==5.10.2) (1.18.0)
# Requirement already satisfied: numpy>=1.17 in .\.venv\Lib\site-packages (from transformers==5.10.2) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from transformers==5.10.2) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in .\.venv\Lib\site-packages (from transformers==5.10.2) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in .\.venv\Lib\site-packages (from transformers==5.10.2) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in .\.venv\Lib\site-packages (from transformers==5.10.2) (0.22.2)
# Requirement already satisfied: typer in .\.venv\Lib\site-packages (from transformers==5.10.2) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in .\.venv\Lib\site-packages (from transformers==5.10.2) (0.8.0rc1)
# Requirement already satisfied: tqdm>=4.27 in .\.venv\Lib\site-packages (from transformers==5.10.2) (4.68.1)
# Requirement already satisfied: click>=8.4.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (3.29.1)
# Requirement already satisfied: fsspec>=2023.5.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (4.15.0)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (4.13.0)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (1.0.9)
# Requirement already satisfied: idna in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (3.18)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\Lib\site-packages (from typer->transformers==5.10.2) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in .\.venv\Lib\site-packages (from typer->transformers==5.10.2) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from typer->transformers==5.10.2) (0.0.4)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.5.0->transformers==5.10.2) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers==5.10.2) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers==5.10.2) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers==5.10.2) (0.1.2)

# %%
# !pip freeze > requirements.txt

# %%
import torch
torch.cuda.is_available()
# Out:
# True
